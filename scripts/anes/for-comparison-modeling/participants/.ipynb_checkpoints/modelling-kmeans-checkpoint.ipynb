# %% [markdown]
# # k-means modelling

# %% [markdown]
# ## 1. dataset and embedding
# * data: concatenated
# * word-embedding: distilbert

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from umap import UMAP

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_distilbert_mentions.jsonl", orient = 'index')

# %%
# "transform embedding"
from ast import literal_eval
emb['embeddings'] = emb['embeddings'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['embeddings'].values)
matrix.shape
# Out:
# (7298, 768)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 768)

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 2

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 2, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.4558143615722656
# Calinski-Harabasz Index: 6724.006615153454
# Davies-Bouldin Index: 0.8489241932843051

# %% [markdown]
# ## 2. dataset and embedding
# * data: concatenated
# * word-embedding: word2vec

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_word2vec_mentions.jsonl", orient = 'index')

# %%
# "transform embedding"
from ast import literal_eval
emb['embeddings'] = emb['embeddings'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['embeddings'].values)
matrix.shape
# Out:
# (7298, 300)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 300)

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 2

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 2, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.2355309945902946
# Calinski-Harabasz Index: 432.05273196372497
# Davies-Bouldin Index: 2.77490951916348

# %% [markdown]
# ## 3. dataset and embedding
# * data: concatenated
# * word-embedding: glove

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_glove_mentions.jsonl", orient = 'index')

# %%
emb
# Out:
#                                                  mentions  \
# 200015            racim blacks whites false information
# 200022                          coming together country
# 200039  severe political polarization allow compromise...
# 200046  pandemic covid 19 unemployment lot people loss...
# 200053  globalism fake covid law order blm public educ...
# ...                                                   ...
# 535315         unity people harming coming together one
# 535360      divisiveness divided unified race inequality
# 535414          health immigration way separate families
# 535421  bias main stream media border control illegal ...
# 535469  pandemic totally control equapilty issue racia...
#
#                                                embeddings
# 200015  [-0.2308297604, -0.1573502421, -0.2432750016, ...
# 200022  [-0.23055869340000001, 0.2900223434, 0.1191700...
# 200039  [-0.0239808857, 0.0263355542, 0.0540418625, 0....
# 200046  [-0.022091141, 0.1731004417, -0.1327654272, -0...
# 200053  [-0.0227783415, -0.0764956623, 0.1342699528, -...
# ...                                                   ...
# 535315  [-0.0271683391, 0.0610709973, -0.070283331, -0...
# 535360  [0.2189160138, 0.1652334034, 0.045131996300000...
# 535414  [0.095422402, 0.20819398760000002, -0.09705319...
# 535421  [-0.2043236196, 0.1852887571, -0.2579542398, 0...
# 535469  [-0.078222394, -0.0090455972, 0.1111977324, -0...
#
# [7298 rows x 2 columns]

# %%
# "transform embedding"
from ast import literal_eval
emb['embeddings'] = emb['embeddings'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['embeddings'].values)
matrix.shape
# Out:
# (7298, 300)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 300)

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 6

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 2, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.1266995714905109
# Calinski-Harabasz Index: 546.8670426717947
# Davies-Bouldin Index: 3.375583066224833

# %% [markdown]
# ## 4. dataset and embedding
# * data: flat embedding
# * word-embedding: distilbert

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from umap import UMAP

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_distilbert_mentions_flat.jsonl", orient = 'index')

# %%
emb
# Out:
#                                             mentions_flat
# 200015  [-0.0944291651, 0.11583015320000001, -0.522738...
# 200022  [-0.227941528, -0.2221784741, 0.0722830296, -0...
# 200039  [-0.31465277080000004, -0.1669896692, -0.14315...
# 200046  [-0.44672465320000004, -0.21085768940000002, -...
# 200053  [-0.1235457361, -0.0382902212, -0.2772190571, ...
# ...                                                   ...
# 535315  [-0.18662181500000002, -0.2441559881, -0.31757...
# 535360  [-0.4200305045, -0.1860999614, -0.5927527547, ...
# 535414  [0.0080013424, 0.04567587, -0.1501371413, -0.0...
# 535421  [-0.1836773306, -0.052328009200000004, 0.03928...
# 535469  [-0.37182012200000003, -0.1018584669, -0.26205...
#
# [7298 rows x 1 columns]

# %%
# "transform embedding"
from ast import literal_eval
emb['mentions_flat'] = emb['mentions_flat'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['mentions_flat'].values)
matrix.shape
# Out:
# (7298, 2304)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 2304)

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 2

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 2, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.8557911515235901
# Calinski-Harabasz Index: 92862.56369333583
# Davies-Bouldin Index: 0.18217327430676475

# %% [markdown]
# ## 5. dataset and embedding
# * data: flat embedding
# * word-embedding: word2vec

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_word2vec_mentions_flat.jsonl", orient = 'index')

# %%
emb
# Out:
#                                             mentions_flat
# 200015  [0.0197753906, -0.0796718597, 0.0830841064, -0...
# 200022  [-0.026041666, 0.0813802108, 0.0262451172, 0.1...
# 200039  [0.024068197200000002, -0.014530181900000001, ...
# 200046  [0.1806640625, -0.54296875, 0.0059204102, 0.59...
# 200053  [0.06853692980000001, 0.0031908208000000003, 0...
# ...                                                   ...
# 535315  [0.0773111954, 0.0376586914, 0.0357666016, 0.1...
# 535360  [0.1032714844, 0.020263671900000002, 0.0012613...
# 535414  [-0.07421875, 0.1127929688, 0.0947265625, 0.07...
# 535421  [-0.034667968800000004, -0.0194091797, 0.00842...
# 535469  [0.140625, -0.22102864090000002, -0.0124308271...
#
# [7298 rows x 1 columns]

# %%
# "transform embedding"
from ast import literal_eval
emb['mentions_flat'] = emb['mentions_flat'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['mentions_flat'].values)
matrix.shape
# Out:
# (7298, 900)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 900)

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 4

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 4, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.13430365739556077
# Calinski-Harabasz Index: 289.05414248383124
# Davies-Bouldin Index: 3.2873129869853583

# %% [markdown]
# ## 6. dataset and embedding
# * data: flat embedding
# * word-embedding: glove

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_glove_mentions_flat.jsonl", orient = 'index')

# %%
emb
# Out:
#                                             mentions_flat
# 200015  [-0.2308297604, -0.1573502421, -0.2432750016, ...
# 200022  [-0.23055869340000001, 0.2900223434, 0.1191700...
# 200039  [-0.14190165700000001, -0.0474033356, 0.027152...
# 200046  [-0.12949000300000002, -0.0235114992, 0.252577...
# 200053  [-0.005518920300000001, -0.0498059951, 0.06463...
# ...                                                   ...
# 535315  [-0.0271683391, 0.0610709973, -0.070283331, -0...
# 535360  [0.39239668850000003, 0.1452720016, -0.0641700...
# 535414  [0.07747200130000001, 0.33504998680000003, 0.1...
# 535421  [-0.0538800023, 0.11378400030000001, -0.085615...
# 535469  [-0.09119299800000001, -0.0280033257, 0.048123...
#
# [7298 rows x 1 columns]

# %%
# "transform embedding"
from ast import literal_eval
emb['mentions_flat'] = emb['mentions_flat'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['mentions_flat'].values)
matrix.shape
# Out:
# (7298, 900)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 900)

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 5

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 2, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.13947427780972668
# Calinski-Harabasz Index: 94.73539815846125
# Davies-Bouldin Index: 2.7517924678328023

# %% [markdown]
# ## 7. dataset and embedding
# * data: mean embedding
# * word-embedding: distilbert

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from umap import UMAP

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_distilbert_mentions_mean.jsonl", orient = 'index')

# %%
emb
# Out:
#                                             mentions_mean
# 200015  [-0.0314763884, 0.0386100511, -0.1742462516, -...
# 200022  [-0.0759805093, -0.0740594914, 0.0240943432, -...
# 200039  [-0.15026521680000002, -0.1103845884, -0.10263...
# 200046  [-0.1957150598, -0.0617878518, -0.134287744700...
# 200053  [-0.0684372634, -0.024012153300000002, -0.1661...
# ...                                                   ...
# 535315  [-0.062207271700000004, -0.0813853294, -0.1058...
# 535360  [-0.22463344540000002, -0.0432103785, -0.28807...
# 535414  [-0.0554608752, -0.0208102949, -0.138257429000...
# 535421  [-0.1116762708, -0.0194018137, -0.0656199244, ...
# 535469  [-0.1816969812, -0.0508102812, -0.2504089872, ...
#
# [7298 rows x 1 columns]

# %%
# "transform embedding"
from ast import literal_eval
emb['mentions_mean'] = emb['mentions_mean'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['mentions_mean'].values)
matrix.shape
# Out:
# (7298, 768)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 768)

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 2

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 2, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.8726393580436707
# Calinski-Harabasz Index: 112930.74021246014
# Davies-Bouldin Index: 0.1596013834970649

# %% [markdown]
# ## 8. dataset and embedding
# * data: mean embedding
# * word-embedding: word2vec

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from umap import UMAP

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_word2vec_mentions_mean.jsonl", orient = 'index')

# %%
emb
# Out:
#                                             mentions_mean
# 200015  [0.0065917969, -0.0265572866, 0.0276947021, -0...
# 200022  [-0.0086805553, 0.0271267369, 0.00874837240000...
# 200039  [-0.0267537441, 0.0208184992, -0.0219184024000...
# 200046  [0.106254071, -0.1744059244, -0.035160318, 0.2...
# 200053  [0.057296599000000004, -0.0079153429, 0.060788...
# ...                                                   ...
# 535315  [0.0257703985, 0.0125528971, 0.0119222005, 0.0...
# 535360  [0.0620320638, -0.019449869800000002, -0.02712...
# 535414  [-0.026285807300000002, 0.0383300781, 0.010884...
# 535421  [-0.022969563800000002, 0.016805013, 0.0169067...
# 535469  [0.0726434911, -0.0716128863, 0.0099504258, 0....
#
# [7298 rows x 1 columns]

# %%
# "transform embedding"
from ast import literal_eval
emb['mentions_mean'] = emb['mentions_mean'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['mentions_mean'].values)
matrix.shape
# Out:
# (7298, 300)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 300)

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 2

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 7, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.36658504605293274
# Calinski-Harabasz Index: 5018.252277146727
# Davies-Bouldin Index: 0.7336675182595133

# %% [markdown]
# ## 9. dataset and embedding
# * data: mean embedding
# * word-embedding: glove

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from umap import UMAP

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# ### UMAP

# %%
# Read the embedding file. Check generating procedure from the 'generate_embedding.ipynb' file. 
emb = pd.read_json("~/thesis/embeddings/response_glove_mentions_mean.jsonl", orient = 'index')

# %%
emb
# Out:
#                                             mentions_mean
# 200015  [-0.0769432535, -0.0524500807, -0.081091667200...
# 200022  [-0.0768528978, 0.0966741145, 0.0397233342, 0....
# 200039  [0.0233196666, 0.0421366691, 0.0449909338, 0.0...
# 200046  [-0.0362072003, 0.0760778983, -0.011441807, -0...
# 200053  [-0.0209387005, -0.0598936516, 0.1127253125000...
# ...                                                   ...
# 535315  [-0.009056113000000001, 0.020356999100000002, ...
# 535360  [0.1170305635, 0.11348250010000001, 0.04830499...
# 535414  [0.059127335700000005, 0.170509994, 0.00429616...
# 535421  [-0.1362157451, 0.12352583310000001, -0.171969...
# 535469  [-0.0553909168, -0.0107698312, 0.0583632228, -...
#
# [7298 rows x 1 columns]

# %%
# "transform embedding"
from ast import literal_eval
emb['mentions_mean'] = emb['mentions_mean'].apply(np.array)  # convert list to numpy array
matrix = np.vstack(emb['mentions_mean'].values)
matrix.shape
# Out:
# (7298, 300)

# %%
X = matrix.copy()

# %%
X.shape
# Out:
# (7298, 300)

# %%
# Step 1: Normalize the data
normalized_embeddings = StandardScaler().fit_transform(X)

# %%
# Step 2: Apply UMAP for dimensionality reduction
umap_model = UMAP(n_neighbors=10, min_dist=0.1, n_components=2, random_state=0)
umap_embeddings = umap_model.fit_transform(normalized_embeddings)
X = umap_embeddings.copy()

# %% [markdown]
# ### silhouette score

# %%
# Step 3: Use silhouette score to find optimal number of clusters
silhouette_scores = []
for num_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_scores.append(silhouette_score(X, cluster_labels))

optimal_num_clusters = silhouette_scores.index(max(silhouette_scores)) + 2

# %% [markdown]
# The last line derives from the fact that silhouette score is calculated from the num_cluster 2, so therefore if retrieving index of the lists, the first element's index is 0 but it indicates the value of num_cluster 2, therefore +2 would make it easier to retrieve the value.

# %%
optimal_num_clusters
# Out:
# 9

# %% [markdown]
# ### elbow method

# %%
# Use Elbow-analysis as well to find optimal number of clusters
# Elbow analysis
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 20)

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
# Create a figure with subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))  # Adjust figsize as needed

# Plot the first plot on ax1
ax1.plot(K, distortions, 'bx-')
ax1.set_xlabel('Values of_K')
ax1.set_ylabel('Distortion')
ax1.set_title('The Elbow Method using Distortion')


# Plot the second plot on ax2
ax2.plot(K, inertias, 'bx-')
ax2.set_xlabel('Values of_K')
ax2.set_ylabel('Inertia')
ax2.set_title('The Elbow Method using Inertia')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## KMeans clustering

# %%
# Step 4: Perform final clustering
final_kmeans = KMeans(n_clusters = 9, random_state=0)
final_cluster_labels = final_kmeans.fit_predict(X)

# Save the result of clustering with random state 0 as a dataframe column
emb['random_0'] = final_cluster_labels

# %%
# Visualize clustering depending on different random states.
figures = [] # list to hold different figures. 

fig1, ax1 = plt.subplots()
scatter = ax1.scatter(X[:, 0], X[:, 1], c=final_cluster_labels, cmap='viridis')
ax1.set_xlabel('UMAP Dimension 1')
ax1.set_ylabel('UMAP Dimension 2')
ax1.set_title('UMAP Visualization of Text Clusters')

colorbar = plt.colorbar(scatter, ax=ax1)
colorbar.set_label('Cluster Label')

figures.append(fig1)

# %%
# Cluster labels obtained from clustering algorithm

final_cluster_labels # cluster_labels_from_bert
X # contextualized tokens of the input texts.

# Specify the question that is addressed. 
print("\n\"Question 1\"\n")

# Calculate Silhouette Coefficient
silhouette = silhouette_score(X, final_cluster_labels)
print(f"Silhouette Coefficient: {silhouette}")

# Calculate Calinski-Harabasz Index
calinski = calinski_harabasz_score(X, final_cluster_labels)
print(f"Calinski-Harabasz Index: {calinski}")

# Calculate Davies-Bouldin Index
davies_bouldin = davies_bouldin_score(X, final_cluster_labels)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# "Question 1"
#
# Silhouette Coefficient: 0.3907475769519806
# Calinski-Harabasz Index: 4994.609197311704
# Davies-Bouldin Index: 0.6569790563996655
